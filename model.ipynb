# %%
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import HTML
# %matplotlib inline
import pandas as pd
import numpy as np

# %% [markdown]
# # Data import

# %%
from dataPreprocessing import preprocess_data,split_time_series,preprocess_data_with_PCA

lag_step_for_SanJuan = 15
lag_step_for_Iquitos = 20

sanJuan_data, iquitos_data = preprocess_data('dengue_features_train.csv',
                                    labels_path="dengue_labels_train.csv",
                                    lag_step_for_SanJuan = lag_step_for_SanJuan,
                                    lag_step_for_Iquitos = lag_step_for_Iquitos)


sanJuan_features = sanJuan_data.drop('total_cases', axis=1)
sanJuan_targets = sanJuan_data['total_cases']

iquitos_features = iquitos_data.drop('total_cases', axis=1)
iquitos_targets = iquitos_data['total_cases']
# Out:
# /Users/chanpreetsingh/Desktop/internship/dengue evolved/dataPreprocessing.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[column + "_time - " + str(lag)] = dataframe[column].shift(lag)  # copy the previous value
# /Users/chanpreetsingh/Desktop/internship/dengue evolved/dataPreprocessing.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe.interpolate(method='linear', limit_direction='forward', axis=0, inplace=True)
# /Users/chanpreetsingh/anaconda3/envs/tensorflow_env/lib/python3.7/site-packages/pandas/core/frame.py:4239: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   **kwargs

# %% [markdown]
# # Training

# %%
import py_compile
py_compile.compile('hyperParameterTuning.py')
test_set_ratio = 0.3 
X_sj_train, X_sj_test, y_sj_train, y_sj_test = split_time_series(sanJuan_features, sanJuan_targets, test_set_ratio)
X_iq_train, X_iq_test, y_iq_train, y_iq_test = split_time_series(iquitos_features, iquitos_targets, test_set_ratio)

# %% [markdown]
# ##  Hyperparameter tuning for San Juan with Gradient Boosting (histGradientBoosting)

# %%
from hyperParameterTuning import find_best_params_histGradientBoosting, find_best_params_RandomForest

# %%
parameters1_SanJuan = [10,20,50,100,200,300,500]
parameters2_SanJuan = [10,16,32,64,128,256]
parameters3_SanJuan=[4, 8, 16, 32]
parameter4_SanJuan=[10,16,32,64,128,256]
param1_sj_1, param2_sj_1,param3_sj_1,param4_sj_1, scores__mean_absulute_error_sj = find_best_params_histGradientBoosting(X_sj_train,
                                                                                 y_sj_train,
                                                                                 X_sj_test,
                                                                                 y_sj_test,
                                                                                 parameters1_SanJuan,
                                                                                 parameters2_SanJuan,
                                                                                 parameters3_SanJuan,
                                                                                 parameter4_SanJuan)
# Out:
# mean_absolute_error [max_iter,max_leaf_nodes]: mean absolute error
# mean_absolute_error [10,10,4,10]: 26.34878692261786
# mean_absolute_error [10,10,4,16]: 26.70579330478401
# mean_absolute_error [10,10,4,32]: 26.61305973457644
# mean_absolute_error [10,10,4,64]: 26.640734279414957
# mean_absolute_error [10,10,4,128]: 26.58107051177665
# mean_absolute_error [10,10,4,256]: 26.73356157284543
# mean_absolute_error [10,10,8,10]: 26.030408226293744
# mean_absolute_error [10,10,8,16]: 26.665397595259606
# mean_absolute_error [10,10,8,32]: 26.51618199586126
# mean_absolute_error [10,10,8,64]: 26.57431738458075
# mean_absolute_error [10,10,8,128]: 26.46457199704114
# mean_absolute_error [10,10,8,256]: 26.77106795579212
# mean_absolute_error [10,10,16,10]: 26.030408226293744
# mean_absolute_error [10,10,16,16]: 26.665397595259606
# mean_absolute_error [10,10,16,32]: 26.51618199586126
# mean_absolute_error [10,10,16,64]: 26.57431738458075
# mean_absolute_error [10,10,16,128]: 26.46457199704114
# mean_absolute_error [10,10,16,256]: 26.77106795579212
# mean_absolute_error [10,10,32,10]: 26.030408226293744
# mean_absolute_error [10,10,32,16]: 26.665397595259606
# mean_absolute_error [10,10,32,32]: 26.51618199586126
# mean_absolute_error [10,10,32,64]: 26.57431738458075
# mean_absolute_error [10,10,32,128]: 26.46457199704114
# mean_absolute_error [10,10,32,256]: 26.77106795579212
# mean_absolute_error [10,16,4,10]: 26.48110804457746
# mean_absolute_error [10,16,4,16]: 26.703017049355893
# mean_absolute_error [10,16,4,32]: 26.668751694479493
# mean_absolute_error [10,16,4,64]: 26.68527914644071
# mean_absolute_error [10,16,4,128]: 26.63951856547556
# mean_absolute_error [10,16,4,256]: 26.901149848107078
# mean_absolute_error [10,16,8,10]: 26.491259422010913
# mean_absolute_error [10,16,8,16]: 26.97690147957028
# mean_absolute_error [10,16,8,32]: 26.722599703326683
# mean_absolute_error [10,16,8,64]: 26.87448960481017
# mean_absolute_error [10,16,8,128]: 26.662656582983054
# mean_absolute_error [10,16,8,256]: 27.040570796105484
# mean_absolute_error [10,16,16,10]: 26.491259422010913
# mean_absolute_error [10,16,16,16]: 26.97690147957028
# mean_absolute_error [10,16,16,32]: 26.722599703326683
# mean_absolute_error [10,16,16,64]: 26.8706512104181
# mean_absolute_error [10,16,16,128]: 26.662656582983054
# mean_absolute_error [10,16,16,256]: 27.045215248141616
# mean_absolute_error [10,16,32,10]: 26.491259422010913
# mean_absolute_error [10,16,32,16]: 26.97690147957028
# mean_absolute_error [10,16,32,32]: 26.722599703326683
# mean_absolute_error [10,16,32,64]: 26.8706512104181
# mean_absolute_error [10,16,32,128]: 26.662656582983054
# mean_absolute_error [10,16,32,256]: 27.045215248141616
# mean_absolute_error [10,32,4,10]: 26.48110804457746
# mean_absolute_error [10,32,4,16]: 26.703017049355893
# mean_absolute_error [10,32,4,32]: 26.668751694479493
# mean_absolute_error [10,32,4,64]: 26.68527914644071
# mean_absolute_error [10,32,4,128]: 26.63951856547556
# mean_absolute_error [10,32,4,256]: 26.901149848107078
# mean_absolute_error [10,32,8,10]: 26.617826068104232
# mean_absolute_error [10,32,8,16]: 27.22482314238575
# mean_absolute_error [10,32,8,32]: 26.964015990653284
# mean_absolute_error [10,32,8,64]: 27.064089248449008
# mean_absolute_error [10,32,8,128]: 26.890945394657685
# mean_absolute_error [10,32,8,256]: 27.295390447487968
# mean_absolute_error [10,32,16,10]: 26.626493912136443
# mean_absolute_error [10,32,16,16]: 27.23657797941033
# mean_absolute_error [10,32,16,32]: 26.959807574910684
# mean_absolute_error [10,32,16,64]: 27.06757601367282
# mean_absolute_error [10,32,16,128]: 26.88901435573661
# mean_absolute_error [10,32,16,256]: 27.305042926622498
# mean_absolute_error [10,32,32,10]: 26.626493912136443
# mean_absolute_error [10,32,32,16]: 27.23657797941033
# mean_absolute_error [10,32,32,32]: 26.959807574910684
# mean_absolute_error [10,32,32,64]: 27.06757601367282
# mean_absolute_error [10,32,32,128]: 26.88901435573661
# mean_absolute_error [10,32,32,256]: 27.305042926622498
# mean_absolute_error [10,64,4,10]: 26.48110804457746
# mean_absolute_error [10,64,4,16]: 26.703017049355893
# mean_absolute_error [10,64,4,32]: 26.668751694479493
# mean_absolute_error [10,64,4,64]: 26.68527914644071
# mean_absolute_error [10,64,4,128]: 26.63951856547556
# mean_absolute_error [10,64,4,256]: 26.901149848107078
# mean_absolute_error [10,64,8,10]: 26.617826068104232
# mean_absolute_error [10,64,8,16]: 27.22482314238575
# mean_absolute_error [10,64,8,32]: 26.964015990653284
# mean_absolute_error [10,64,8,64]: 27.064089248449008
# mean_absolute_error [10,64,8,128]: 26.890945394657685
# mean_absolute_error [10,64,8,256]: 27.295390447487968
# mean_absolute_error [10,64,16,10]: 26.626493912136443
# mean_absolute_error [10,64,16,16]: 27.23657797941033
# mean_absolute_error [10,64,16,32]: 26.959807574910684
# mean_absolute_error [10,64,16,64]: 27.06757601367282
# mean_absolute_error [10,64,16,128]: 26.88901435573661
# mean_absolute_error [10,64,16,256]: 27.305042926622498
# mean_absolute_error [10,64,32,10]: 26.626493912136443
# mean_absolute_error [10,64,32,16]: 27.23657797941033
# mean_absolute_error [10,64,32,32]: 26.959807574910684
# mean_absolute_error [10,64,32,64]: 27.06757601367282
# mean_absolute_error [10,64,32,128]: 26.88901435573661
# mean_absolute_error [10,64,32,256]: 27.305042926622498
# mean_absolute_error [10,128,4,10]: 26.48110804457746
# mean_absolute_error [10,128,4,16]: 26.703017049355893
# mean_absolute_error [10,128,4,32]: 26.668751694479493
# mean_absolute_error [10,128,4,64]: 26.68527914644071
# mean_absolute_error [10,128,4,128]: 26.63951856547556
# mean_absolute_error [10,128,4,256]: 26.901149848107078
# mean_absolute_error [10,128,8,10]: 26.617826068104232
# mean_absolute_error [10,128,8,16]: 27.22482314238575
# mean_absolute_error [10,128,8,32]: 26.964015990653284
# mean_absolute_error [10,128,8,64]: 27.064089248449008
# mean_absolute_error [10,128,8,128]: 26.890945394657685
# mean_absolute_error [10,128,8,256]: 27.295390447487968
# mean_absolute_error [10,128,16,10]: 26.626493912136443
# mean_absolute_error [10,128,16,16]: 27.23657797941033
# mean_absolute_error [10,128,16,32]: 26.959807574910684
# mean_absolute_error [10,128,16,64]: 27.06757601367282
# mean_absolute_error [10,128,16,128]: 26.88901435573661
# mean_absolute_error [10,128,16,256]: 27.305042926622498
# mean_absolute_error [10,128,32,10]: 26.626493912136443
# mean_absolute_error [10,128,32,16]: 27.23657797941033
# mean_absolute_error [10,128,32,32]: 26.959807574910684
# mean_absolute_error [10,128,32,64]: 27.06757601367282
# mean_absolute_error [10,128,32,128]: 26.88901435573661
# mean_absolute_error [10,128,32,256]: 27.305042926622498
# mean_absolute_error [10,256,4,10]: 26.48110804457746
# mean_absolute_error [10,256,4,16]: 26.703017049355893
# mean_absolute_error [10,256,4,32]: 26.668751694479493
# mean_absolute_error [10,256,4,64]: 26.68527914644071
# mean_absolute_error [10,256,4,128]: 26.63951856547556
# mean_absolute_error [10,256,4,256]: 26.901149848107078
# mean_absolute_error [10,256,8,10]: 26.617826068104232
# mean_absolute_error [10,256,8,16]: 27.22482314238575
# mean_absolute_error [10,256,8,32]: 26.964015990653284
# mean_absolute_error [10,256,8,64]: 27.064089248449008
# mean_absolute_error [10,256,8,128]: 26.890945394657685
# mean_absolute_error [10,256,8,256]: 27.295390447487968
# mean_absolute_error [10,256,16,10]: 26.626493912136443
# mean_absolute_error [10,256,16,16]: 27.23657797941033
# mean_absolute_error [10,256,16,32]: 26.959807574910684
# mean_absolute_error [10,256,16,64]: 27.06757601367282
# mean_absolute_error [10,256,16,128]: 26.88901435573661
# mean_absolute_error [10,256,16,256]: 27.305042926622498
# mean_absolute_error [10,256,32,10]: 26.626493912136443
# mean_absolute_error [10,256,32,16]: 27.23657797941033
# mean_absolute_error [10,256,32,32]: 26.959807574910684
# mean_absolute_error [10,256,32,64]: 27.06757601367282
# mean_absolute_error [10,256,32,128]: 26.88901435573661
# mean_absolute_error [10,256,32,256]: 27.305042926622498
# mean_absolute_error [20,10,4,10]: 25.24191528501202
# mean_absolute_error [20,10,4,16]: 25.73697048871925
# mean_absolute_error [20,10,4,32]: 25.66772083236128
# mean_absolute_error [20,10,4,64]: 25.92574019794531
# mean_absolute_error [20,10,4,128]: 25.971912335099884
# mean_absolute_error [20,10,4,256]: 26.167611957364283
# mean_absolute_error [20,10,8,10]: 24.806702791702634
# mean_absolute_error [20,10,8,16]: 26.05974785663986
# mean_absolute_error [20,10,8,32]: 25.60658636811856
# mean_absolute_error [20,10,8,64]: 25.675604416987444
# mean_absolute_error [20,10,8,128]: 25.6620425602062
# mean_absolute_error [20,10,8,256]: 26.24542439934454
# mean_absolute_error [20,10,16,10]: 24.806702791702634
# mean_absolute_error [20,10,16,16]: 26.05974785663986
# mean_absolute_error [20,10,16,32]: 25.60658636811856
# mean_absolute_error [20,10,16,64]: 25.675604416987444
# mean_absolute_error [20,10,16,128]: 25.6620425602062
# mean_absolute_error [20,10,16,256]: 26.24542439934454
# mean_absolute_error [20,10,32,10]: 24.806702791702634
# mean_absolute_error [20,10,32,16]: 26.05974785663986
# mean_absolute_error [20,10,32,32]: 25.60658636811856
# mean_absolute_error [20,10,32,64]: 25.675604416987444
# mean_absolute_error [20,10,32,128]: 25.6620425602062
# mean_absolute_error [20,10,32,256]: 26.24542439934454
# mean_absolute_error [20,16,4,10]: 25.2220880005575
# mean_absolute_error [20,16,4,16]: 25.98084037811408
# mean_absolute_error [20,16,4,32]: 25.61457972440929
# mean_absolute_error [20,16,4,64]: 25.952400766548074
# mean_absolute_error [20,16,4,128]: 26.033754417211046
# mean_absolute_error [20,16,4,256]: 26.301211247082087
# mean_absolute_error [20,16,8,10]: 25.44004966747576
# mean_absolute_error [20,16,8,16]: 26.45935259326319
# mean_absolute_error [20,16,8,32]: 26.137955431088905
# mean_absolute_error [20,16,8,64]: 26.138422818976984
# mean_absolute_error [20,16,8,128]: 26.15059521455796
# mean_absolute_error [20,16,8,256]: 26.431633607731726
# mean_absolute_error [20,16,16,10]: 25.44004966747576
# mean_absolute_error [20,16,16,16]: 26.45935259326319
# mean_absolute_error [20,16,16,32]: 26.137955431088905
# mean_absolute_error [20,16,16,64]: 26.105942398758614
# mean_absolute_error [20,16,16,128]: 26.15059521455796
# mean_absolute_error [20,16,16,256]: 26.460975788919292
# mean_absolute_error [20,16,32,10]: 25.44004966747576
# mean_absolute_error [20,16,32,16]: 26.45935259326319
# mean_absolute_error [20,16,32,32]: 26.137955431088905
# mean_absolute_error [20,16,32,64]: 26.105942398758614
# mean_absolute_error [20,16,32,128]: 26.15059521455796
# mean_absolute_error [20,16,32,256]: 26.460975788919292
# mean_absolute_error [20,32,4,10]: 25.2220880005575
# mean_absolute_error [20,32,4,16]: 25.98084037811408
# mean_absolute_error [20,32,4,32]: 25.61457972440929
# mean_absolute_error [20,32,4,64]: 25.952400766548074
# mean_absolute_error [20,32,4,128]: 26.033754417211046
# mean_absolute_error [20,32,4,256]: 26.301211247082087
# mean_absolute_error [20,32,8,10]: 25.67493554116579
# mean_absolute_error [20,32,8,16]: 26.829292780225824
# mean_absolute_error [20,32,8,32]: 26.458205786616713
# mean_absolute_error [20,32,8,64]: 26.297382683158425
# mean_absolute_error [20,32,8,128]: 26.372297084668908
# mean_absolute_error [20,32,8,256]: 26.629023840113405
# mean_absolute_error [20,32,16,10]: 25.686804485916472
# mean_absolute_error [20,32,16,16]: 26.83761000666003
# mean_absolute_error [20,32,16,32]: 26.51782013625184
# mean_absolute_error [20,32,16,64]: 26.36727961994171
# mean_absolute_error [20,32,16,128]: 26.392131858209545
# mean_absolute_error [20,32,16,256]: 26.659545791842675
# mean_absolute_error [20,32,32,10]: 25.686804485916472
# mean_absolute_error [20,32,32,16]: 26.83761000666003
# mean_absolute_error [20,32,32,32]: 26.51782013625184
# mean_absolute_error [20,32,32,64]: 26.36727961994171
# mean_absolute_error [20,32,32,128]: 26.392131858209545
# mean_absolute_error [20,32,32,256]: 26.659545791842675
# mean_absolute_error [20,64,4,10]: 25.2220880005575
# mean_absolute_error [20,64,4,16]: 25.98084037811408
# mean_absolute_error [20,64,4,32]: 25.61457972440929
# mean_absolute_error [20,64,4,64]: 25.952400766548074
# mean_absolute_error [20,64,4,128]: 26.033754417211046
# mean_absolute_error [20,64,4,256]: 26.301211247082087
# mean_absolute_error [20,64,8,10]: 25.67493554116579
# mean_absolute_error [20,64,8,16]: 26.829292780225824
# mean_absolute_error [20,64,8,32]: 26.458205786616713
# mean_absolute_error [20,64,8,64]: 26.297382683158425
# mean_absolute_error [20,64,8,128]: 26.372297084668908
# mean_absolute_error [20,64,8,256]: 26.629023840113405
# mean_absolute_error [20,64,16,10]: 25.686804485916472
# mean_absolute_error [20,64,16,16]: 26.83761000666003
# mean_absolute_error [20,64,16,32]: 26.51782013625184
# mean_absolute_error [20,64,16,64]: 26.36727961994171
# mean_absolute_error [20,64,16,128]: 26.392131858209545
# mean_absolute_error [20,64,16,256]: 26.659545791842675
# mean_absolute_error [20,64,32,10]: 25.686804485916472
# mean_absolute_error [20,64,32,16]: 26.83761000666003
# mean_absolute_error [20,64,32,32]: 26.51782013625184
# mean_absolute_error [20,64,32,64]: 26.36727961994171
# mean_absolute_error [20,64,32,128]: 26.392131858209545
# mean_absolute_error [20,64,32,256]: 26.659545791842675
# mean_absolute_error [20,128,4,10]: 25.2220880005575
# mean_absolute_error [20,128,4,16]: 25.98084037811408
# mean_absolute_error [20,128,4,32]: 25.61457972440929
# mean_absolute_error [20,128,4,64]: 25.952400766548074
# mean_absolute_error [20,128,4,128]: 26.033754417211046
# mean_absolute_error [20,128,4,256]: 26.301211247082087
# mean_absolute_error [20,128,8,10]: 25.67493554116579
# mean_absolute_error [20,128,8,16]: 26.829292780225824
# mean_absolute_error [20,128,8,32]: 26.458205786616713
# mean_absolute_error [20,128,8,64]: 26.297382683158425
# mean_absolute_error [20,128,8,128]: 26.372297084668908
# mean_absolute_error [20,128,8,256]: 26.629023840113405
# mean_absolute_error [20,128,16,10]: 25.686804485916472
# mean_absolute_error [20,128,16,16]: 26.83761000666003
# mean_absolute_error [20,128,16,32]: 26.51782013625184
# mean_absolute_error [20,128,16,64]: 26.36727961994171
# mean_absolute_error [20,128,16,128]: 26.392131858209545
# mean_absolute_error [20,128,16,256]: 26.659545791842675
# mean_absolute_error [20,128,32,10]: 25.686804485916472
# mean_absolute_error [20,128,32,16]: 26.83761000666003
# mean_absolute_error [20,128,32,32]: 26.51782013625184
# mean_absolute_error [20,128,32,64]: 26.36727961994171
# mean_absolute_error [20,128,32,128]: 26.392131858209545
# mean_absolute_error [20,128,32,256]: 26.659545791842675
# mean_absolute_error [20,256,4,10]: 25.2220880005575
# mean_absolute_error [20,256,4,16]: 25.98084037811408
# mean_absolute_error [20,256,4,32]: 25.61457972440929
# mean_absolute_error [20,256,4,64]: 25.952400766548074
# mean_absolute_error [20,256,4,128]: 26.033754417211046
# mean_absolute_error [20,256,4,256]: 26.301211247082087
# mean_absolute_error [20,256,8,10]: 25.67493554116579
# mean_absolute_error [20,256,8,16]: 26.829292780225824
# mean_absolute_error [20,256,8,32]: 26.458205786616713
# mean_absolute_error [20,256,8,64]: 26.297382683158425
# mean_absolute_error [20,256,8,128]: 26.372297084668908
# mean_absolute_error [20,256,8,256]: 26.629023840113405
# mean_absolute_error [20,256,16,10]: 25.686804485916472
# mean_absolute_error [20,256,16,16]: 26.83761000666003
# mean_absolute_error [20,256,16,32]: 26.51782013625184
# mean_absolute_error [20,256,16,64]: 26.36727961994171
# mean_absolute_error [20,256,16,128]: 26.392131858209545
# mean_absolute_error [20,256,16,256]: 26.659545791842675
# mean_absolute_error [20,256,32,10]: 25.686804485916472
# mean_absolute_error [20,256,32,16]: 26.83761000666003
# mean_absolute_error [20,256,32,32]: 26.51782013625184
# mean_absolute_error [20,256,32,64]: 26.36727961994171
# mean_absolute_error [20,256,32,128]: 26.392131858209545
# mean_absolute_error [20,256,32,256]: 26.659545791842675
# mean_absolute_error [50,10,4,10]: 24.179471162026207
# mean_absolute_error [50,10,4,16]: 25.133989655880228
# mean_absolute_error [50,10,4,32]: 24.902263416830372
# mean_absolute_error [50,10,4,64]: 25.394097011768874
# mean_absolute_error [50,10,4,128]: 25.143999843072763
# mean_absolute_error [50,10,4,256]: 25.1539586046503
# mean_absolute_error [50,10,8,10]: 24.11968480590973
# mean_absolute_error [50,10,8,16]: 25.13195008036814
# mean_absolute_error [50,10,8,32]: 24.749757093039896
# mean_absolute_error [50,10,8,64]: 25.34441303730797
# mean_absolute_error [50,10,8,128]: 24.485713337057643
# mean_absolute_error [50,10,8,256]: 25.16148728673798
# mean_absolute_error [50,10,16,10]: 24.11968480590973
# mean_absolute_error [50,10,16,16]: 25.13195008036814
# mean_absolute_error [50,10,16,32]: 24.749757093039896
# mean_absolute_error [50,10,16,64]: 25.34441303730797
# mean_absolute_error [50,10,16,128]: 24.485713337057643
# mean_absolute_error [50,10,16,256]: 25.16148728673798
# mean_absolute_error [50,10,32,10]: 24.11968480590973
# mean_absolute_error [50,10,32,16]: 25.13195008036814
# mean_absolute_error [50,10,32,32]: 24.749757093039896
# mean_absolute_error [50,10,32,64]: 25.34441303730797
# mean_absolute_error [50,10,32,128]: 24.485713337057643
# mean_absolute_error [50,10,32,256]: 25.16148728673798
# mean_absolute_error [50,16,4,10]: 24.49198635975286
# mean_absolute_error [50,16,4,16]: 24.848964537011003
# mean_absolute_error [50,16,4,32]: 25.007638581327154
# mean_absolute_error [50,16,4,64]: 25.781419738283372
# mean_absolute_error [50,16,4,128]: 25.064657446162183
# mean_absolute_error [50,16,4,256]: 25.267302023897138
# mean_absolute_error [50,16,8,10]: 25.320737811902152
# mean_absolute_error [50,16,8,16]: 25.922792018537375
# mean_absolute_error [50,16,8,32]: 25.227837841887364
# mean_absolute_error [50,16,8,64]: 25.782940566327543
# mean_absolute_error [50,16,8,128]: 25.56443099451721
# mean_absolute_error [50,16,8,256]: 25.7522909941276
# mean_absolute_error [50,16,16,10]: 25.210738011461896
# mean_absolute_error [50,16,16,16]: 26.081070830809143
# mean_absolute_error [50,16,16,32]: 25.429455264101907
# mean_absolute_error [50,16,16,64]: 25.65987252335362
# mean_absolute_error [50,16,16,128]: 25.561022049016447
# mean_absolute_error [50,16,16,256]: 25.67046978140051
# mean_absolute_error [50,16,32,10]: 25.210738011461896
# mean_absolute_error [50,16,32,16]: 26.081070830809143
# mean_absolute_error [50,16,32,32]: 25.429455264101907
# mean_absolute_error [50,16,32,64]: 25.65987252335362
# mean_absolute_error [50,16,32,128]: 25.561022049016447
# mean_absolute_error [50,16,32,256]: 25.67046978140051
# mean_absolute_error [50,32,4,10]: 24.49198635975286
# mean_absolute_error [50,32,4,16]: 24.848964537011003
# mean_absolute_error [50,32,4,32]: 25.007638581327154
# mean_absolute_error [50,32,4,64]: 25.781419738283372
# mean_absolute_error [50,32,4,128]: 25.064657446162183
# mean_absolute_error [50,32,4,256]: 25.267302023897138
# mean_absolute_error [50,32,8,10]: 25.35467213991359
# mean_absolute_error [50,32,8,16]: 26.237735881868527
# mean_absolute_error [50,32,8,32]: 26.090088685313987
# mean_absolute_error [50,32,8,64]: 25.897039845161906
# mean_absolute_error [50,32,8,128]: 25.615169989785908
# mean_absolute_error [50,32,8,256]: 26.095995692930256
# mean_absolute_error [50,32,16,10]: 25.470840781683552
# mean_absolute_error [50,32,16,16]: 26.08307700514325
# mean_absolute_error [50,32,16,32]: 26.217452176875025
# mean_absolute_error [50,32,16,64]: 26.1320948194907
# mean_absolute_error [50,32,16,128]: 25.639135618011327
# mean_absolute_error [50,32,16,256]: 26.385111813495133
# mean_absolute_error [50,32,32,10]: 25.470840781683552
# mean_absolute_error [50,32,32,16]: 26.08307700514325
# mean_absolute_error [50,32,32,32]: 26.216278556948385
# mean_absolute_error [50,32,32,64]: 26.1320948194907
# mean_absolute_error [50,32,32,128]: 25.643806628042363
# mean_absolute_error [50,32,32,256]: 26.384734105950603
# mean_absolute_error [50,64,4,10]: 24.49198635975286
# mean_absolute_error [50,64,4,16]: 24.848964537011003
# mean_absolute_error [50,64,4,32]: 25.007638581327154
# mean_absolute_error [50,64,4,64]: 25.781419738283372
# mean_absolute_error [50,64,4,128]: 25.064657446162183
# mean_absolute_error [50,64,4,256]: 25.267302023897138
# mean_absolute_error [50,64,8,10]: 25.35467213991359
# mean_absolute_error [50,64,8,16]: 26.237735881868527
# mean_absolute_error [50,64,8,32]: 26.090088685313987
# mean_absolute_error [50,64,8,64]: 25.897039845161906
# mean_absolute_error [50,64,8,128]: 25.615169989785908
# mean_absolute_error [50,64,8,256]: 26.095995692930256
# mean_absolute_error [50,64,16,10]: 25.470840781683552
# mean_absolute_error [50,64,16,16]: 26.08307700514325
# mean_absolute_error [50,64,16,32]: 26.217452176875025
# mean_absolute_error [50,64,16,64]: 26.1320948194907
# mean_absolute_error [50,64,16,128]: 25.639135618011327
# mean_absolute_error [50,64,16,256]: 26.385111813495133
# mean_absolute_error [50,64,32,10]: 25.470840781683552
# mean_absolute_error [50,64,32,16]: 26.08307700514325
# mean_absolute_error [50,64,32,32]: 26.216278556948385
# mean_absolute_error [50,64,32,64]: 26.1320948194907
# mean_absolute_error [50,64,32,128]: 25.643806628042363
# mean_absolute_error [50,64,32,256]: 26.384734105950603
# mean_absolute_error [50,128,4,10]: 24.49198635975286
# mean_absolute_error [50,128,4,16]: 24.848964537011003
# mean_absolute_error [50,128,4,32]: 25.007638581327154
# mean_absolute_error [50,128,4,64]: 25.781419738283372
# mean_absolute_error [50,128,4,128]: 25.064657446162183
# mean_absolute_error [50,128,4,256]: 25.267302023897138
# mean_absolute_error [50,128,8,10]: 25.35467213991359
# mean_absolute_error [50,128,8,16]: 26.237735881868527
# mean_absolute_error [50,128,8,32]: 26.090088685313987
# mean_absolute_error [50,128,8,64]: 25.897039845161906
# mean_absolute_error [50,128,8,128]: 25.615169989785908
# mean_absolute_error [50,128,8,256]: 26.095995692930256
# mean_absolute_error [50,128,16,10]: 25.470840781683552
# mean_absolute_error [50,128,16,16]: 26.08307700514325
# mean_absolute_error [50,128,16,32]: 26.217452176875025
# mean_absolute_error [50,128,16,64]: 26.1320948194907
# mean_absolute_error [50,128,16,128]: 25.639135618011327
# mean_absolute_error [50,128,16,256]: 26.385111813495133
# mean_absolute_error [50,128,32,10]: 25.470840781683552
# mean_absolute_error [50,128,32,16]: 26.08307700514325
# mean_absolute_error [50,128,32,32]: 26.216278556948385
# mean_absolute_error [50,128,32,64]: 26.1320948194907
# mean_absolute_error [50,128,32,128]: 25.643806628042363
# mean_absolute_error [50,128,32,256]: 26.384734105950603
# mean_absolute_error [50,256,4,10]: 24.49198635975286
# mean_absolute_error [50,256,4,16]: 24.848964537011003
# mean_absolute_error [50,256,4,32]: 25.007638581327154
# mean_absolute_error [50,256,4,64]: 25.781419738283372
# mean_absolute_error [50,256,4,128]: 25.064657446162183
# mean_absolute_error [50,256,4,256]: 25.267302023897138
# mean_absolute_error [50,256,8,10]: 25.35467213991359
# mean_absolute_error [50,256,8,16]: 26.237735881868527
# mean_absolute_error [50,256,8,32]: 26.090088685313987
# mean_absolute_error [50,256,8,64]: 25.897039845161906
# mean_absolute_error [50,256,8,128]: 25.615169989785908
# mean_absolute_error [50,256,8,256]: 26.095995692930256
# mean_absolute_error [50,256,16,10]: 25.470840781683552
# mean_absolute_error [50,256,16,16]: 26.08307700514325
# mean_absolute_error [50,256,16,32]: 26.217452176875025
# mean_absolute_error [50,256,16,64]: 26.1320948194907
# mean_absolute_error [50,256,16,128]: 25.639135618011327
# mean_absolute_error [50,256,16,256]: 26.385111813495133
# mean_absolute_error [50,256,32,10]: 25.470840781683552
# mean_absolute_error [50,256,32,16]: 26.08307700514325
# mean_absolute_error [50,256,32,32]: 26.216278556948385
# mean_absolute_error [50,256,32,64]: 26.1320948194907
# mean_absolute_error [50,256,32,128]: 25.643806628042363
# mean_absolute_error [50,256,32,256]: 26.384734105950603
# mean_absolute_error [100,10,4,10]: 25.068665089840973
# mean_absolute_error [100,10,4,16]: 25.457811957287603
# mean_absolute_error [100,10,4,32]: 25.627816210936597
# mean_absolute_error [100,10,4,64]: 26.248144738929508
# mean_absolute_error [100,10,4,128]: 25.691244797114656
# mean_absolute_error [100,10,4,256]: 25.6343319634245
# mean_absolute_error [100,10,8,10]: 25.322844878801664
# mean_absolute_error [100,10,8,16]: 26.106584927193296
# mean_absolute_error [100,10,8,32]: 25.81630436522734
# mean_absolute_error [100,10,8,64]: 25.993471492506476
# mean_absolute_error [100,10,8,128]: 25.307593674766686
# mean_absolute_error [100,10,8,256]: 25.78653205698813
# mean_absolute_error [100,10,16,10]: 25.322844878801664
# mean_absolute_error [100,10,16,16]: 26.106584927193296
# mean_absolute_error [100,10,16,32]: 25.81630436522734
# mean_absolute_error [100,10,16,64]: 25.993471492506476
# mean_absolute_error [100,10,16,128]: 25.338504749772774
# mean_absolute_error [100,10,16,256]: 25.78653205698813
# mean_absolute_error [100,10,32,10]: 25.322844878801664
# mean_absolute_error [100,10,32,16]: 26.106584927193296
# mean_absolute_error [100,10,32,32]: 25.81630436522734
# mean_absolute_error [100,10,32,64]: 25.993471492506476
# mean_absolute_error [100,10,32,128]: 25.338504749772774
# mean_absolute_error [100,10,32,256]: 25.78653205698813
# mean_absolute_error [100,16,4,10]: 25.31825857265063
# mean_absolute_error [100,16,4,16]: 25.48998586494791
# mean_absolute_error [100,16,4,32]: 25.937320944236244
# mean_absolute_error [100,16,4,64]: 26.374007796552704
# mean_absolute_error [100,16,4,128]: 25.48462154621098
# mean_absolute_error [100,16,4,256]: 25.751329827934352
# mean_absolute_error [100,16,8,10]: 26.320598107306015
# mean_absolute_error [100,16,8,16]: 26.72658345855016
# mean_absolute_error [100,16,8,32]: 26.53982019742675
# mean_absolute_error [100,16,8,64]: 27.03361918955251
# mean_absolute_error [100,16,8,128]: 26.833588375818845
# mean_absolute_error [100,16,8,256]: 26.730801823152408
# mean_absolute_error [100,16,16,10]: 26.472690765272805
# mean_absolute_error [100,16,16,16]: 26.8290030450584
# mean_absolute_error [100,16,16,32]: 26.953242014774258
# mean_absolute_error [100,16,16,64]: 27.001136348580317
# mean_absolute_error [100,16,16,128]: 26.50467555692677
# mean_absolute_error [100,16,16,256]: 26.800246165794643
# mean_absolute_error [100,16,32,10]: 26.472690765272805
# mean_absolute_error [100,16,32,16]: 26.8290030450584
# mean_absolute_error [100,16,32,32]: 26.953242014774258
# mean_absolute_error [100,16,32,64]: 27.001136348580317
# mean_absolute_error [100,16,32,128]: 26.50467555692677
# mean_absolute_error [100,16,32,256]: 26.800246165794643
# mean_absolute_error [100,32,4,10]: 25.31825857265063
# mean_absolute_error [100,32,4,16]: 25.48998586494791
# mean_absolute_error [100,32,4,32]: 25.937320944236244
# mean_absolute_error [100,32,4,64]: 26.374007796552704
# mean_absolute_error [100,32,4,128]: 25.48462154621098
# mean_absolute_error [100,32,4,256]: 25.751329827934352
# mean_absolute_error [100,32,8,10]: 26.47491198522464
# mean_absolute_error [100,32,8,16]: 27.488587572707615
# mean_absolute_error [100,32,8,32]: 27.149932434592998
# mean_absolute_error [100,32,8,64]: 27.160618190714814
# mean_absolute_error [100,32,8,128]: 26.645030179750623
# mean_absolute_error [100,32,8,256]: 27.19426710249648
# mean_absolute_error [100,32,16,10]: 27.08346047845917
# mean_absolute_error [100,32,16,16]: 27.237279556460226
# mean_absolute_error [100,32,16,32]: 27.4885509017451
# mean_absolute_error [100,32,16,64]: 27.235907406689492
# mean_absolute_error [100,32,16,128]: 26.90022949679544
# mean_absolute_error [100,32,16,256]: 27.395318477959986
# mean_absolute_error [100,32,32,10]: 27.08346047845917
# mean_absolute_error [100,32,32,16]: 27.282301010788135
# mean_absolute_error [100,32,32,32]: 27.52263466257023
# mean_absolute_error [100,32,32,64]: 27.3326208044476
# mean_absolute_error [100,32,32,128]: 26.786656635045293
# mean_absolute_error [100,32,32,256]: 27.38937943753742
# mean_absolute_error [100,64,4,10]: 25.31825857265063
# mean_absolute_error [100,64,4,16]: 25.48998586494791
# mean_absolute_error [100,64,4,32]: 25.937320944236244
# mean_absolute_error [100,64,4,64]: 26.374007796552704
# mean_absolute_error [100,64,4,128]: 25.48462154621098
# mean_absolute_error [100,64,4,256]: 25.751329827934352
# mean_absolute_error [100,64,8,10]: 26.47491198522464
# mean_absolute_error [100,64,8,16]: 27.488587572707615
# mean_absolute_error [100,64,8,32]: 27.149932434592998
# mean_absolute_error [100,64,8,64]: 27.160618190714814
# mean_absolute_error [100,64,8,128]: 26.645030179750623
# mean_absolute_error [100,64,8,256]: 27.19426710249648
# mean_absolute_error [100,64,16,10]: 27.08346047845917
# mean_absolute_error [100,64,16,16]: 27.237279556460226
# mean_absolute_error [100,64,16,32]: 27.4885509017451
# mean_absolute_error [100,64,16,64]: 27.235907406689492
# mean_absolute_error [100,64,16,128]: 26.90022949679544
# mean_absolute_error [100,64,16,256]: 27.395318477959986
# mean_absolute_error [100,64,32,10]: 27.08346047845917
# mean_absolute_error [100,64,32,16]: 27.282301010788135
# mean_absolute_error [100,64,32,32]: 27.52263466257023
# mean_absolute_error [100,64,32,64]: 27.3326208044476
# mean_absolute_error [100,64,32,128]: 26.786656635045293
# mean_absolute_error [100,64,32,256]: 27.38937943753742
# mean_absolute_error [100,128,4,10]: 25.31825857265063
# mean_absolute_error [100,128,4,16]: 25.48998586494791
# mean_absolute_error [100,128,4,32]: 25.937320944236244
# mean_absolute_error [100,128,4,64]: 26.374007796552704
# mean_absolute_error [100,128,4,128]: 25.48462154621098
# mean_absolute_error [100,128,4,256]: 25.751329827934352
# mean_absolute_error [100,128,8,10]: 26.47491198522464
# mean_absolute_error [100,128,8,16]: 27.488587572707615
# mean_absolute_error [100,128,8,32]: 27.149932434592998
# mean_absolute_error [100,128,8,64]: 27.160618190714814
# mean_absolute_error [100,128,8,128]: 26.645030179750623
# mean_absolute_error [100,128,8,256]: 27.19426710249648
# mean_absolute_error [100,128,16,10]: 27.08346047845917
# mean_absolute_error [100,128,16,16]: 27.237279556460226
# mean_absolute_error [100,128,16,32]: 27.4885509017451
# mean_absolute_error [100,128,16,64]: 27.235907406689492
# mean_absolute_error [100,128,16,128]: 26.90022949679544
# mean_absolute_error [100,128,16,256]: 27.395318477959986
# mean_absolute_error [100,128,32,10]: 27.08346047845917
# mean_absolute_error [100,128,32,16]: 27.282301010788135
# mean_absolute_error [100,128,32,32]: 27.52263466257023
# mean_absolute_error [100,128,32,64]: 27.3326208044476
# mean_absolute_error [100,128,32,128]: 26.786656635045293
# mean_absolute_error [100,128,32,256]: 27.38937943753742
# mean_absolute_error [100,256,4,10]: 25.31825857265063
# mean_absolute_error [100,256,4,16]: 25.48998586494791
# mean_absolute_error [100,256,4,32]: 25.937320944236244
# mean_absolute_error [100,256,4,64]: 26.374007796552704
# mean_absolute_error [100,256,4,128]: 25.48462154621098
# mean_absolute_error [100,256,4,256]: 25.751329827934352
# mean_absolute_error [100,256,8,10]: 26.47491198522464
# mean_absolute_error [100,256,8,16]: 27.488587572707615
# mean_absolute_error [100,256,8,32]: 27.149932434592998
# mean_absolute_error [100,256,8,64]: 27.160618190714814
# mean_absolute_error [100,256,8,128]: 26.645030179750623
# mean_absolute_error [100,256,8,256]: 27.19426710249648
# mean_absolute_error [100,256,16,10]: 27.08346047845917
# mean_absolute_error [100,256,16,16]: 27.237279556460226
# mean_absolute_error [100,256,16,32]: 27.4885509017451
# mean_absolute_error [100,256,16,64]: 27.235907406689492
# mean_absolute_error [100,256,16,128]: 26.90022949679544
# mean_absolute_error [100,256,16,256]: 27.395318477959986
# mean_absolute_error [100,256,32,10]: 27.08346047845917
# mean_absolute_error [100,256,32,16]: 27.282301010788135
# mean_absolute_error [100,256,32,32]: 27.52263466257023
# mean_absolute_error [100,256,32,64]: 27.3326208044476
# mean_absolute_error [100,256,32,128]: 26.786656635045293
# mean_absolute_error [100,256,32,256]: 27.38937943753742
# mean_absolute_error [200,10,4,10]: 26.664745466146698
# mean_absolute_error [200,10,4,16]: 27.560475080918817
# mean_absolute_error [200,10,4,32]: 27.261517039129554
# mean_absolute_error [200,10,4,64]: 27.314168907823756
# mean_absolute_error [200,10,4,128]: 26.90595291496817
# mean_absolute_error [200,10,4,256]: 26.661448765089798
# mean_absolute_error [200,10,8,10]: 27.789243550301936
# mean_absolute_error [200,10,8,16]: 27.9381463595213
# mean_absolute_error [200,10,8,32]: 27.584629180583345
# mean_absolute_error [200,10,8,64]: 27.62071571462876
# mean_absolute_error [200,10,8,128]: 26.80532732362651
# mean_absolute_error [200,10,8,256]: 27.171257334346684
# mean_absolute_error [200,10,16,10]: 27.70721797256101
# mean_absolute_error [200,10,16,16]: 27.86422160341543
# mean_absolute_error [200,10,16,32]: 27.694729859898473
# mean_absolute_error [200,10,16,64]: 27.912817433949446
# mean_absolute_error [200,10,16,128]: 26.536393628400482
# mean_absolute_error [200,10,16,256]: 27.09029710695023
# mean_absolute_error [200,10,32,10]: 27.70721797256101
# mean_absolute_error [200,10,32,16]: 27.86422160341543
# mean_absolute_error [200,10,32,32]: 27.694729859898473
# mean_absolute_error [200,10,32,64]: 27.912817433949446
# mean_absolute_error [200,10,32,128]: 26.536393628400482
# mean_absolute_error [200,10,32,256]: 27.09029710695023
# mean_absolute_error [200,16,4,10]: 27.334337002395785
# mean_absolute_error [200,16,4,16]: 27.29012093892592
# mean_absolute_error [200,16,4,32]: 26.964806757489665
# mean_absolute_error [200,16,4,64]: 27.5119089798507
# mean_absolute_error [200,16,4,128]: 26.385789330435177
# mean_absolute_error [200,16,4,256]: 26.978326423769758
# mean_absolute_error [200,16,8,10]: 28.61784403718289
# mean_absolute_error [200,16,8,16]: 28.944329152185023
# mean_absolute_error [200,16,8,32]: 28.36654633069721
# mean_absolute_error [200,16,8,64]: 29.08612576994531
# mean_absolute_error [200,16,8,128]: 28.42793458560982
# mean_absolute_error [200,16,8,256]: 28.547183079534644
# mean_absolute_error [200,16,16,10]: 28.388281253547778
# mean_absolute_error [200,16,16,16]: 28.893527980676172
# mean_absolute_error [200,16,16,32]: 28.33829704110024
# mean_absolute_error [200,16,16,64]: 29.003751921905565
# mean_absolute_error [200,16,16,128]: 28.24841722214689
# mean_absolute_error [200,16,16,256]: 28.251109660215114
# mean_absolute_error [200,16,32,10]: 28.388281253547778
# mean_absolute_error [200,16,32,16]: 28.893527980676172
# mean_absolute_error [200,16,32,32]: 28.33829704110024
# mean_absolute_error [200,16,32,64]: 29.003751921905565
# mean_absolute_error [200,16,32,128]: 28.24841722214689
# mean_absolute_error [200,16,32,256]: 28.251109660215114
# mean_absolute_error [200,32,4,10]: 27.334337002395785
# mean_absolute_error [200,32,4,16]: 27.29012093892592

# %%
plt.figure(figsize=(8, 6))
plt.subplots_adjust(left=.2, right=0.95, bottom=0.15, top=0.95)
plt.imshow(scores__mean_absulute_error_sj, interpolation='nearest', cmap=plt.cm.hot_r)
plt.ylabel('alpha')
plt.xlabel('--')
plt.colorbar()
plt.yticks(np.arange(len(parameters1_SanJuan)), parameters1_SanJuan, rotation=45)
plt.xticks(np.arange(len(parameters2_SanJuan)), parameters2_SanJuan)
plt.title('Validation accuracy for San Juan')
plt.show()

# %% [markdown]
# ## Hyperparameter tuning for  Iquitos  with Gradient Boosting (histGradientBoosting)

# %%
parameters1_Iquitos = [10,20,50,100,200,300,500]
parameters2_Iquitos = [10,16,32,64,128,256]
parameters3_Iquitos =  [4, 8, 16, 32]
parameter4_Iquitos=[10,16,32,64,128,256]
param1_iq_1, param2_iq_1,param3_iq_1,param4_iq_1, scores__mean_absulute_error_iq = find_best_params_histGradientBoosting(X_iq_train,
                                                                                 y_iq_train,
                                                                                 X_iq_test,
                                                                                 y_iq_test,
                                                                                 parameters1_Iquitos,
                                                                                 parameters2_Iquitos,
                                                                                 parameters2_Iquitos,parameter4_Iquitos)

# %%
plt.figure(figsize=(8, 6))
plt.subplots_adjust(left=.2, right=0.95, bottom=0.15, top=0.95)
plt.imshow(scores__mean_absulute_error_iq, interpolation='nearest', cmap=plt.cm.hot_r)
plt.ylabel('n_estimators')
plt.xlabel('max_depth')
plt.colorbar()
plt.yticks(np.arange(len(parameters1_Iquitos)), parameters1_Iquitos, rotation=45)
plt.xticks(np.arange(len(parameters2_Iquitos)), parameters2_Iquitos)
plt.title('Validation accuracy for Iquitos')
plt.show()

# %% [markdown]
# ## Hyperparameter tuning for San Juan with RandomForest

# %%
parameters1_SanJuan = [10,20,50,100,200,300,500]
parameters2_SanJuan = [10,15,20,40,50,100]

param1_sj_2, param2_sj_2, scores__mean_absulute_error_sj = find_best_params_RandomForest(X_sj_train,
                                                                                 y_sj_train,
                                                                                 X_sj_test,
                                                                                 y_sj_test,
                                                                                 parameters1_SanJuan,
                                                                                 parameters2_SanJuan)

# %%
plt.figure(figsize=(8, 6))
plt.subplots_adjust(left=.2, right=0.95, bottom=0.15, top=0.95)
plt.imshow(scores__mean_absulute_error_sj, interpolation='nearest', cmap=plt.cm.hot_r)
plt.ylabel('alpha')
plt.xlabel('--')
plt.colorbar()
plt.yticks(np.arange(len(parameters1_SanJuan)), parameters1_SanJuan, rotation=45)
plt.xticks(np.arange(len(parameters2_SanJuan)), parameters2_SanJuan)
plt.title('Validation accuracy for San Juan')
plt.show()

# %% [markdown]
# ## Hyperparameter tuning for Iquitos with RandomForest

# %%
parameters1_Iquitos = [20,50,100,200,300,400,500]
parameters2_Iquitos = [10,15,20,40]

param1_iq_2, param2_iq_2, scores__mean_absulute_error_iq = find_best_params_RandomForest(X_iq_train,
                                                                                 y_iq_train,
                                                                                 X_iq_test,
                                                                                 y_iq_test,
                                                                                 parameters1_Iquitos,
                                                                                 parameters2_Iquitos)

# %%
plt.figure(figsize=(8, 6))
plt.subplots_adjust(left=.2, right=0.95, bottom=0.15, top=0.95)
plt.imshow(scores__mean_absulute_error_iq, interpolation='nearest', cmap=plt.cm.hot_r)
plt.ylabel('n_estimators')
plt.xlabel('max_depth')
plt.colorbar()
plt.yticks(np.arange(len(parameters1_Iquitos)), parameters1_Iquitos, rotation=45)
plt.xticks(np.arange(len(parameters2_Iquitos)), parameters2_Iquitos)
plt.title('Validation accuracy for Iquitos')
plt.show()

# %% [markdown]
#  ## Final evaluation of models

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.experimental import enable_hist_gradient_boosting  
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
best_sj_HistGradientBoosting = HistGradientBoostingRegressor(loss='least_squares',
                                     learning_rate=0.05,
                                     max_iter=param1_sj_1,
                                     max_leaf_nodes=param2_sj_1,
                                     max_depth=param3_sj_1,
                                     min_samples_leaf=20,
                                     l2_regularization=0.6,
                                     max_bins=param4_sj_1,
                                     scoring=None,
                                     validation_fraction=0.6,
                                     n_iter_no_change=None,
                                     tol=1e-07, 
                                     verbose=0,
                                     random_state=0)
best_iq_HistGradientBoosting = HistGradientBoostingRegressor(loss='least_squares',
                                     learning_rate=0.05,
                                     max_iter=param1_iq_1,
                                     max_leaf_nodes=param2_iq_1,
                                     max_depth=param3_iq_1,
                                     min_samples_leaf=20,
                                     l2_regularization=0.6,
                                     max_bins=param4_iq_1,
                                     scoring=None,
                                     validation_fraction=0.6,
                                     n_iter_no_change=None,
                                     tol=1e-07, 
                                     verbose=0,
                                     random_state=0)

best_sj_RandomForest = RandomForestRegressor(n_estimators=param1_sj_2,
                                              max_depth=param2_sj_2,
                                              criterion='mse',
                                              random_state=0,
                                              warm_start = True,
                                              n_jobs=8)

best_iq_RandomForest = RandomForestRegressor(n_estimators=param1_iq_2,
                                              max_depth=param2_iq_2,
                                              criterion='mse',
                                              random_state=0,
                                              warm_start = True,
                                              n_jobs=8)

# %%
best_sj_HistGradientBoosting.fit(X_sj_train,y_sj_train)
best_iq_HistGradientBoosting.fit(X_iq_train,y_iq_train)

# %%
predictions_sj_HistGradientBoosting = best_sj_HistGradientBoosting.predict(X_sj_test)
predictions_iq_HistGradientBoosting = best_iq_HistGradientBoosting.predict(X_iq_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

print("For San Juan\n ")
print("mean_squared_error: {0}".format(mean_squared_error(y_sj_test, predictions_sj)))
print("mean_absolute_error: {0}".format(mean_absolute_error(y_sj_test, predictions_sj)))


df1 = pd.DataFrame({"predicted":predictions_sj,"actual":y_sj_test})

df1.plot()
plt.title('San Juan: predicted vs actual')
plt.xlabel('Time')
plt.legend()

# %%
print("\nFor Iquitos\n ")
print("mean_squared_error: {0}".format(mean_squared_error(y_iq_test, predictions_iq)))
print("mean_absolute_error: {0}".format(mean_absolute_error(y_iq_test, predictions_iq)))

df2 = pd.DataFrame({"predicted":predictions_iq,"actual":y_iq_test})

df2.plot()
plt.title('Iquitos: predicted vs actual')
plt.xlabel('Time')

plt.legend()

# %%
predictions_sj = best_sj_RandomForest.predict(sanJuan_features)
predictions_iq = best_iq_RandomForest.predict(iquitos_features)
#predictions_sj = best_sj_HistGradientBoosting.predict(sanJuan_features)
#predictions_iq = best_iq_HistGradientBoosting.predict(iquitos_features)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

print("For San Juan\n ")
print("mean_squared_error: {0}".format(mean_squared_error(sanJuan_targets, predictions_sj)))
print("mean_absolute_error: {0}".format(mean_absolute_error(sanJuan_targets, predictions_sj)))

df1 = pd.DataFrame({"predicted":predictions_sj,"actual":sanJuan_targets})

df1.plot()
plt.title('San Juan: predicted vs actual')
plt.xlabel('Time')
plt.legend()

# %%
print("\nFor Iquitos\n ")
print("mean_squared_error: {0}".format(mean_squared_error(iquitos_targets, predictions_iq)))
print("mean_absolute_error: {0}".format(mean_absolute_error(iquitos_targets, predictions_iq)))


df2 = pd.DataFrame({"predicted":predictions_iq,"actual":iquitos_targets})

df2.plot()
plt.title('Iquitos: predicted vs actual')
plt.xlabel('Time')

plt.legend()

# %% [markdown]
# ## Submissions

# %%
best_sj_HistGradientBoosting.fit(sanJuan_features,sanJuan_targets)
best_iq_HistGradientBoosting.fit(iquitos_features,iquitos_targets)

# %%
sj_test , iq_test = preprocess_data('dengue_features_test.csv',
                                   lag_step_for_SanJuan = lag_step_for_SanJuan,
                                   lag_step_for_Iquitos = lag_step_for_Iquitos)

sj_predictions = best_sj.predict(sj_test).astype(int)
iq_predictions = best_iq.predict(iq_test).astype(int)

submission = pd.read_csv("submission_format.csv",
                         index_col=[0, 1, 2])


submission.total_cases = np.concatenate((sj_predictions, iq_predictions),axis=0)
#submission.to_csv("submissionbest_HistGradientBoosting.csv")
submission.to_csv("submissionbest_RaandomForest.csv")
